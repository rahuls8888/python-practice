# %% [markdown]
# <a href="https://colab.research.google.com/github/rahuls8888/python-practice/blob/main/pandas_and_numpy_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.shape
# Out:
# (78, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   gender      78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.skew()
# Out:
# <ipython-input-10-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# phd        0.634366
# service    0.913750
# salary     0.452103
# dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.kurt()
# Out:
# phd        0.042504
# service    0.608981
# salary    -0.401713
# dtype: float64

# %%
df[['salary','service']]
# Out:
#     salary  service
# 0   186960       49
# 1    93000        6
# 2   110515       20
# 3   131205       31
# 4   104800       18
# ..     ...      ...
# 73  105450       10
# 74  104542        6
# 75  124312       17
# 76  109954       14
# 77  109646       15
#
# [78 rows x 2 columns]

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[0:50,:]
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:20,0:1]
# Out:
#          rank
# 0        Prof
# 1        Prof
# 2        Prof
# 3        Prof
# 4        Prof
# 5        Prof
# 6   AssocProf
# 7        Prof
# 8        Prof
# 9        Prof
# 10       Prof
# 11       Prof
# 12   AsstProf
# 13       Prof
# 14       Prof
# 15       Prof
# 16   AsstProf
# 17   AsstProf
# 18       Prof
# 19       Prof

# %%
df1 = pd.read_csv('Salaries.csv', nrows=1)

# %%
df1
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960

# %%
df.salary>120000
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 73    False
# 74    False
# 75     True
# 76    False
# 77    False
# Name: salary, Length: 78, dtype: bool

# %%
df.groupby(['rank']).mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('Universities.csv')

# %%
plt.hist(df2['Accept'])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sn

# %%
sn.histplot(df2['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
df2
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.plot(df2['SAT'],df2['Accept'] , 'rs')

# %%
sn.scatterplot(x='SAT',y='Accept',data=df2)
# Out:
# <Axes: xlabel='SAT', ylabel='Accept'>

# %%
sn.distplot(df2['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
sn.pairplot(df2)

# %%
df2.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
plt.boxplot(df2['SAT'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a80547ea290>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a80547e8d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a80547e9ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a80547eabf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a80547eae90>],
#  'means': []}

# %%
import numpy as np

# %%
a = np.array([(1,2,3,4),(4,5,6,7)])

# %%
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
b = a.reshape(4,2)

# %%
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
c = np.array([1,2,3,4])

# %%
c.sum()
# Out:
# 10

# %%
a.sum(axis=0)
# Out:
# array([ 5,  7,  9, 11])

# %%
a.sum(axis=1)
# Out:
# array([10, 22])

# %%
dup = pd.DataFrame({'col1':['a','a','b','b','b'],'col2':[2,2,2,3,3]})

# %%
dup
# Out:
#   col1  col2
# 0    a     2
# 1    a     2
# 2    b     2
# 3    b     3
# 4    b     3

# %%
dup.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
d = [1,2,3,4]

# %%
d
# Out:
# [1, 2, 3, 4]

# %%
type(d)
# Out:
# list

# %%
e = pd.Series(d)

# %%
e
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(e)
# Out:
# pandas.core.series.Series

# %%
dict = {'a':10,'b':20,'c':30,'d':40}

# %%
dict
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
pd.Series(dict)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
